# %%
# Interactive plotting 
# %pylab inline

# Data initialize
X = np.loadtxt('Data/train.csv',  delimiter=',', skiprows=1, usecols=range(2, 14))
y = np.loadtxt('Data/train.csv', delimiter=',', skiprows=1, usecols=[14])


temp = X[:,8]
atemp = X[:,9]
hum = X[:,10]
windspd = X[:,11]
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Plot linear relationship between apparent temperature and temperature
plt.plot(atemp, temp, color='black', linestyle=':', linewidth=3,)
plt.xlabel("Apparent Temperature (atemp)", fontsize=10)
plt.ylabel("Temperature (temp)", fontsize = 10)
plt.title("Apparent Temperature vs Temperature")
savefig('Figures/atempvtemp.png')
